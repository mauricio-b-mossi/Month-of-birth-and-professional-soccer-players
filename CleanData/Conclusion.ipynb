# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
from pingouin import corr
import dataframe_image as dfi
import seaborn as sns

# %% [markdown]
# ### Conclusion

# %%
all_df = pd.read_csv('AllMonthNameData.csv')
p99_df = pd.read_csv('99thPercentileMonthNameData.csv')
ch_df = pd.read_csv('ChelseaMonthNameData.csv')

# %%
allN_df = pd.read_csv('all_monthNumerical.csv')
p99N_df = pd.read_csv('p99_monthNumerical.csv')
chN_df = pd.read_csv('ch_monthNumerical.csv')

# %%
allN_df.drop(columns=(['Unnamed: 0']), inplace=True)
p99N_df.drop(columns=(['Unnamed: 0']), inplace=True)
chN_df.drop(columns=(['Unnamed: 0']), inplace=True)

# %%
allN_df['Dataset'] = "All"
p99N_df['Dataset'] = "Top 99th"
chN_df['Dataset'] = "Chelsea"

# %%
chN_df.rename(columns={'Month':'Months'}, inplace=True)

# %% [markdown]
# ### Preparing Data

# %%
all_df.head(1)
# Out:
#    Unnamed: 0   Months  Total Players
# 0           0  January           2103

# %%
p99_df.head(1)
# Out:
#    Unnamed: 0   Months  Total Players
# 0           0  January             19

# %%
ch_df.head(1)
# Out:
#    Unnamed: 0   Months  Total Players
# 0           0  January              3

# %% [markdown]
# ### Dropping Rows

# %%
all_df.drop(columns=(['Unnamed: 0']), inplace=True)
p99_df.drop(columns=(['Unnamed: 0']), inplace=True)
ch_df.drop(columns=(['Unnamed: 0']), inplace=True)

# %%
all_df['Dataset'] = "All"
p99_df['Dataset'] = "Top 99th"
ch_df['Dataset'] = "Chelsea"

# %%
concat_df = pd.concat([all_df, p99_df], ignore_index=True)

# %%
concat_df = pd.concat([concat_df, ch_df], ignore_index=True)

# %%
concat_df
# Out:
#        Months  Total Players   Dataset
# 0     January           2103       All
# 1    February           2204       All
# 2       March           1864       All
# 3       April           1712       All
# 4         May           1630       All
# 5        June           1435       All
# 6        July           1470       All
# 7      August           1404       All
# 8   September           1445       All
# 9     October           1288       All
# 10   November           1239       All
# 11   December           1150       All
# 12    January             19  Top 99th
# 13   February             25  Top 99th
# 14      March             20  Top 99th
# 15      April             18  Top 99th
# 16        May             26  Top 99th
# 17       June             19  Top 99th
# 18       July             14  Top 99th
# 19     August             13  Top 99th
# 20  September             12  Top 99th
# 21    October             12  Top 99th
# 22   November             18  Top 99th
# ...

# %%
concatN_df = pd.concat([allN_df, p99N_df], ignore_index=True)

# %%
concatN_df = pd.concat([concatN_df, chN_df], ignore_index=True)

# %%
concatN_df
# Out:
#     Months  Total Players   Dataset
# 0        1           2103       All
# 1        2           2204       All
# 2        3           1864       All
# 3        4           1712       All
# 4        5           1630       All
# 5        6           1435       All
# 6        7           1470       All
# 7        8           1404       All
# 8        9           1445       All
# 9       10           1288       All
# 10      11           1239       All
# 11      12           1150       All
# 12       0             19  Top 99th
# 13       1             25  Top 99th
# 14       2             20  Top 99th
# 15       3             18  Top 99th
# 16       4             26  Top 99th
# 17       5             19  Top 99th
# 18       6             14  Top 99th
# 19       7             13  Top 99th
# 20       8             12  Top 99th
# 21       9             12  Top 99th
# 22      10             18  Top 99th
# 23      11             16  Top 99th
# 24       1              3   Chelsea
# ...

# %%
sns.violinplot(x='Dataset', y='Months', data=concatN_df)
# Out:
# <AxesSubplot:xlabel='Dataset', ylabel='Months'>
